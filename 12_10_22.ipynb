# %% [markdown]
# <a href="https://colab.research.google.com/github/miregial/python_m_hw/blob/main/12_10_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import requests
import array as arr

# %%
js=requests.get('https://api.hh.ru/vacancies?text=Дизайнер&per_page=100').json()['items']

# %%
js[0]
# Out:
# {'id': '70676017',
#  'premium': False,
#  'name': 'Дизайнер',
#  'department': None,
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': False},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2022-10-12T11:14:37+0300',
#  'created_at': '2022-10-12T11:14:37+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=70676017',
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/70676017?host=hh.ru',
#  'adv_response_url': 'https://api.hh.ru/vacancies/70676017/adv_response?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/70676017',
#  'relations': [],
#  'employer': {'id': '4940016',
#   'name': 'Наймиум',
#   'url': 'https://api.hh.ru/employers/4940016',
# ...

# %%
[[x['id'], x['name'], x['salary'], x['snippet']] for x in js]
# Out:
# [['70676017',
#   'Дизайнер',
#   {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': False},
#   {'requirement': 'У тебя есть опыт работы на аналогичной позиции от 3 лет. Обладаешь отличными навыками работы в графических редакторах (Adobe Photoshop...',
#    'responsibility': 'Создавать дизайн рекламных буклетов и журналов, упаковок и визиток. Заниматься веб-дизайном (страница сайта, оформление в стиле лендинг, баннера, превью...'}],
#  ['70897607',
#   'Графический дизайнер',
#   {'from': 130000, 'to': None, 'currency': 'RUR', 'gross': False},
#   {'requirement': 'Опыт работы в сфере дизайна и верстки полиграфических материалов от 2-х лет. Уверенный пользователь программ ПК, технически грамотная и...',
#    'responsibility': 'Разработка креативных дизайн-концепций проектов. Формирование pos-материалов (буклеты, каталоги, листовки, разнообразные рекламных материалы). Разработка 3D дизайна (устройства, упаковка...'}],
#  ['70818431',
# ...

# %%
t1=tuple((x['id'], x['name']) for x in js)

# %%
t1[0]=('70676017', 'дизайнер111')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ae00ace77369> in <module>
# ----> 1 t1[0]=('70676017', 'дизайнер111')
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple(x[1] for x in t1).count('Дизайнер')
# Out:
# 22

# %%
tuple(x[1] for x in t1).index('Дизайнер')
# Out:
# 0

# %%
l1=[[x['id'], x['name'], x['salary'], x['snippet']] for x in js]

# %%
l1
# Out:
# [['70676017',
#   'Дизайнер',
#   {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': False},
#   {'requirement': 'У тебя есть опыт работы на аналогичной позиции от 3 лет. Обладаешь отличными навыками работы в графических редакторах (Adobe Photoshop...',
#    'responsibility': 'Создавать дизайн рекламных буклетов и журналов, упаковок и визиток. Заниматься веб-дизайном (страница сайта, оформление в стиле лендинг, баннера, превью...'}],
#  ['70897607',
#   'Графический дизайнер',
#   {'from': 130000, 'to': None, 'currency': 'RUR', 'gross': False},
#   {'requirement': 'Опыт работы в сфере дизайна и верстки полиграфических материалов от 2-х лет. Уверенный пользователь программ ПК, технически грамотная и...',
#    'responsibility': 'Разработка креативных дизайн-концепций проектов. Формирование pos-материалов (буклеты, каталоги, листовки, разнообразные рекламных материалы). Разработка 3D дизайна (устройства, упаковка...'}],
#  ['70818431',
# ...

# %%
f=lambda x:[x['salary']['from'],x['salary']['to'],x['salary']['currency'],x['salary']['gross']] if x['salary'] is not None else [None]*4

# %%
l1=[[x['id'], x['name']] +\
    f(x)+\
    [x['snippet']['requirement'], x['snippet']['responsibility']]
    for x in js]

# %%
max([x[3] for x in l1 if x[3] is not None])
# Out:
# 500000

# %%
l1[[x[3] for x in l1].index(max([x[3] for x in l1 if x[3] is not None]))][1]
# Out:
# 'Дизайнер-визуализатор'
