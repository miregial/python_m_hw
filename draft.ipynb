# %% [markdown]
# <a href="https://colab.research.google.com/github/miregial/python_m_hw/blob/main/draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'пол':np.random.choice(['муж','жен'],p=(0.55,0.45), size=100),
              'возраст':np.random.exponential(40, size=100)},index=range(1000,1100))

# %%
df[:5] #- 0-5
# Out:
#       пол    возраст
# 1000  жен  13.818119
# 1001  муж  22.892555
# 1002  муж  17.077103
# 1003  муж   4.269353
# 1004  жен   9.283077

# %%
type(df[:5])
# Out:
# pandas.core.frame.DataFrame

# %%
type(np.random.choice(['муж','жен'],p=(0.55,0.45), size=100))
# Out:
# numpy.ndarray

# %%
type((0.55,0.45))
# Out:
# tuple

# %%
set(np.random.choice(['муж','жен'],p=(0.55,0.45), size=100))
# Out:
# {'жен', 'муж'}

# %%
df.index.tolist()
# Out:
# [1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1009,
#  1010,
#  1011,
#  1012,
#  1013,
#  1014,
#  1015,
#  1016,
#  1017,
#  1018,
#  1019,
#  1020,
#  1021,
#  1022,
#  1023,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1029,
#  1030,
#  1031,
#  1032,
#  1033,
#  1034,
#  1035,
#  1036,
#  1037,
#  1038,
#  1039,
#  1040,
#  1041,
#  1042,
#  1043,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1049,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1066,
#  1067,
#  1068,
#  1069,
#  1070,
#  1071,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1077,
#  1078,
#  1079,
#  1080,
#  1081,
#  1082,
#  1083,
#  1084,
#  1085,
#  1086,
#  1087,
#  1088,
#  1089,
#  1090,
#  1091,
#  1092,
#  1093,
#  1094,
#  1095,
#  1096,
#  1097,
#  1098,
#  1099]

# %%
'|'.join([str(x) for x in df.index.tolist()])
# Out:
# '1000|1001|1002|1003|1004|1005|1006|1007|1008|1009|1010|1011|1012|1013|1014|1015|1016|1017|1018|1019|1020|1021|1022|1023|1024|1025|1026|1027|1028|1029|1030|1031|1032|1033|1034|1035|1036|1037|1038|1039|1040|1041|1042|1043|1044|1045|1046|1047|1048|1049|1050|1051|1052|1053|1054|1055|1056|1057|1058|1059|1060|1061|1062|1063|1064|1065|1066|1067|1068|1069|1070|1071|1072|1073|1074|1075|1076|1077|1078|1079|1080|1081|1082|1083|1084|1085|1086|1087|1088|1089|1090|1091|1092|1093|1094|1095|1096|1097|1098|1099'

# %%
len('|'.join([str(x) for x in df.index.tolist()]).split('01'))
# Out:
# 12

# %%
len(df)
# Out:
# 100

# %%
df.shape #строк и столбцов
# Out:
# (100, 2)

# %%
np.reshape(df.index,(50,2,1)) #3х мерный массив
# Out:
# array([[[1000],
#         [1001]],
#
#        [[1002],
#         [1003]],
#
#        [[1004],
#         [1005]],
#
#        [[1006],
#         [1007]],
#
#        [[1008],
#         [1009]],
#
#        [[1010],
#         [1011]],
#
#        [[1012],
#         [1013]],
#
#        [[1014],
#         [1015]],
#
#        [[1016],
#         [1017]],
#
#        [[1018],
#         [1019]],
#
#        [[1020],
#         [1021]],
#
#        [[1022],
#         [1023]],
#
#        [[1024],
#         [1025]],
#
#        [[1026],
#         [1027]],
#
#        [[1028],
#         [1029]],
#
#        [[1030],
#         [1031]],
#
#        [[1032],
#         [1033]],
#
#        [[1034],
#         [1035]],
#
#        [[1036],
#         [1037]],
#
#        [[1038],
#         [1039]],
#
#        [[1040],
#         [1041]],
#
#        [[1042],
#         [1043]],
#
#        [[1044],
#         [1045]],
#
#        [[1046],
#         [1047]],
#
#        [[1048],
#         [1049]],
#
#        [[1050],
# ...

# %%
len(np.reshape(df.index,(50,2,1)))
# Out:
# 50

# %%
df['возраст'].apply(lambda x: round(x))
# Out:
# 1000     14
# 1001     23
# 1002     17
# 1003      4
# 1004      9
#        ...
# 1095      1
# 1096     52
# 1097     35
# 1098    109
# 1099     69
# Name: возраст, Length: 100, dtype: int64

# %%
type(df['возраст'])
# Out:
# pandas.core.series.Series

# %%
# %%timeit
df[['возраст']].apply(lambda x: x.astype(int),axis=1) #axis 0 = str, axis 1= column
# Out:
# 10.6 ms ± 372 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df[['возраст']].apply(lambda x: round(x))
# Out:
#       возраст
# 1000     14.0
# 1001     23.0
# 1002     17.0
# 1003      4.0
# 1004      9.0
# ...       ...
# 1095      1.0
# 1096     52.0
# 1097     35.0
# 1098    109.0
# 1099     69.0
#
# [100 rows x 1 columns]

# %%
import requests
import re
from sklearn.linear_model import LinearRegression

# %%
'ddsfsffsff{}'.format('dsfsdf')
# Out:
# 'ddsfsffsffdsfsdf'

# %%
'ddsfsffsff{}' % 'dsfsdf'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-c9ec84273848> in <module>
# ----> 1 'ddsfsffsff{}' % 'dsfsdf'
#
# TypeError: not all arguments converted during string formatting

# %%
for i in range(0,20):
requests.get('https://api.hh.ru/vacancies?text=разработчикANDPython&area=1&per_page=100&page')
# Out:
#   File "<ipython-input-63-4074b54aed36>", line 2
#     requests.get('https://api.hh.ru/vacancies?text=разработчикANDPython&area=1&per_page=100&page')
#            ^
# IndentationError: expected an indented block

# %%
requests.get('https://api.hh.ru/vacancies?text=разработчикANDPython&area=1&per_page=100&page'+str(i)).json()
# Out:
# {'items': [{'id': '48457284',
#    'premium': False,
#    'name': 'Разработчик Solidity/Разработчик Rust/Разработчик Go/Разработчик python(удаленно)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 600000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-09-14T01:45:22+0300',
#    'created_at': '2022-09-14T01:45:22+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48457284',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48457284?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/48457284/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48457284',
# ...

# %%
d=pd.DataFrame()
for i in range(0,20):
  d=d.append(pd.DataFrame(requests.get('https://api.hh.ru/vacancies?text=разработчикANDPython&area=1&per_page=100&page'+str(i)).json()['items']))
d.shape
# Out:
# (2000, 29)

# %%
d['id'].nunique()
# Out:
# 100

# %%
d.head(3)
# Out:
#          id  premium                                               name  \
# 0  48457284    False  Разработчик Solidity/Разработчик Rust/Разработ...
# 1  69777761    False                                 Python разработчик
# 2  39736489    False                   Python-разработчик (Django, DRF)
#
#   department  has_test  response_letter_required  \
# 0       None     False                     False
# 1       None      True                     False
# 2       None     False                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                               salary  \
# 0  {'from': 600000, 'to': None, 'currency': 'RUR'...
# 1  {'from': 100000, 'to': 250000, 'currency': 'RU...
# 2  {'from': 60000, 'to': 150000, 'currency': 'RUR...
#
# ...

# %%
d.salary.tolist()
# Out:
# [{'from': 600000, 'to': None, 'currency': 'RUR', 'gross': False},
#  {'from': 100000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#  {'from': 60000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#  {'from': 300000, 'to': 500000, 'currency': 'RUR', 'gross': False},
#  {'from': 250000, 'to': 350000, 'currency': 'RUR', 'gross': False},
#  {'from': 150000, 'to': 300000, 'currency': 'RUR', 'gross': False},
#  {'from': 280000, 'to': 340000, 'currency': 'RUR', 'gross': True},
#  {'from': 80000, 'to': 220000, 'currency': 'RUR', 'gross': True},
#  {'from': 80000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#  None,
#  {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#  None,
#  {'from': 90000, 'to': 140000, 'currency': 'RUR', 'gross': False},
#  {'from': 75000, 'to': 125000, 'currency': 'RUR', 'gross': True},
#  None,
#  {'from': 100000, 'to': 400000, 'currency': 'RUR', 'gross': False},
#  {'from': None, 'to': 110000, 'currency': 'RUR', 'gross': False},
# ...

# %%
def sal(x):
  if (x['from'] is not None) & (x['to'] is not None):
    return np.mean([x['from'], x['to']])
  elif x['from'] is not None:
    return  x['from']
  elif x['from'] is not None:
    return x['to']
  else:
    return None

# %%
[d.salary.tolist()]
# Out:
# [[{'from': 600000, 'to': None, 'currency': 'RUR', 'gross': False},
#   {'from': 100000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#   {'from': 60000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#   {'from': 300000, 'to': 500000, 'currency': 'RUR', 'gross': False},
#   {'from': 250000, 'to': 350000, 'currency': 'RUR', 'gross': False},
#   {'from': 150000, 'to': 300000, 'currency': 'RUR', 'gross': False},
#   {'from': 280000, 'to': 340000, 'currency': 'RUR', 'gross': True},
#   {'from': 80000, 'to': 220000, 'currency': 'RUR', 'gross': True},
#   {'from': 80000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#   None,
#   {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#   None,
#   {'from': 90000, 'to': 140000, 'currency': 'RUR', 'gross': False},
#   {'from': 75000, 'to': 125000, 'currency': 'RUR', 'gross': True},
#   None,
#   {'from': 100000, 'to': 400000, 'currency': 'RUR', 'gross': False},
# ...

# %%
y=[sal(x) if x is not None else None for x in d.salary.tolist()]

# %%
d.snippet.tolist()
# Out:
# [{'requirement': 'Solidity (от 3‐х лет) или Rust (от 3‐х лет) или Go (от 3-х лет) или <highlighttext>Python</highlighttext>(от...',
#   'responsibility': 'Проектировать, кодировать и внедрять бизнес‐приложения. Интегрировать блокчейны с нашей платформой. Работа с API и микросервисами. Разработка и проверка криптографических...'},
#  {'requirement': 'От 1 года коммерческой разработки в команде на <highlighttext>Python</highlighttext>/Django. Опыт использования QT/PySide/PyQT, Docker, Git, Linux. ',
#   'responsibility': 'Работа с большими данными, анализ данных, разработка парсеров и интеграций. Разработка десктопных приложений на QT. Поддержка высоконагруженных систем на микросервисной...'},
#  {'requirement': 'Опыт разработки сложных проектов. Обязателен опыт работы с django 2.*, <highlighttext>python</highlighttext> 3.7, djangorestframework. Знание SQL (в частности, PostgreSQL) и...',
# ...

# %%
[re.findall('[A-Z][A-Za-z]+[\/]?[A-Z][A-Za-z]*',x['requirement']) if x['requirement'] is not None else None for x in d.snippet.tolist()]

# %%
pd.DataFrame([re.findall('[A-Z][A-Za-z]+[\/]?[A-Z][A-Za-z]*',x['requirement']) if x['requirement'] is not None else None for x in d.snippet.tolist()])
# Out:
#               0           1     2     3     4
# 0          None        None  None  None  None
# 1     QT/PySide        PyQT  None  None  None
# 2           SQL  PostgreSQL  None  None  None
# 3           NET        None  None  None  None
# 4          None        None  None  None  None
# ...         ...         ...   ...   ...   ...
# 1995        UML        BPNM  None  None  None
# 1996       REST  SQLAlchemy  None  None  None
# 1997       None        None  None  None  None
# 1998        API        None  None  None  None
# 1999        SQL        None  None  None  None
#
# [2000 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
model=TfidfVectorizer()
x0=[','.join(re.findall('[A-Z][A-Za-z]+[\/]?[A-Z][A-Za-z]*',x['requirement'])) if x['requirement'] is not None else None for x in d.snippet.tolist()]
x1=model.fit_transform(x0)
x=pd.DataFrame(x1.toarray(),columns=model.get_feature_names())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
Environment

# %%
'https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name'
# Out:
# 'https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name'

# %%
URL = 'https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name'

# %%
import requests
import re
from sklearn.linear_model import LinearRegression

# %%
#requests.get('https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name')

# %%
#for i in range(0,20):
#  requests.get('https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name')

# %%
#requests.get('https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name'+str(i)).json()

# %%
import requests
#json with id,name

# %%
#requests.get('https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name').json()

# %%
arequests.get('https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name').text
# Out:
# '{"items":[{"id":"70029179","premium":false,"name":"Бизнес аналитик/Data аналитик (Elma)","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"Москва","url":"https://api.hh.ru/areas/1"},"salary":{"from":150000,"to":170000,"currency":"RUR","gross":true},"type":{"id":"open","name":"Открытая"},"address":null,"response_url":null,"sort_point_distance":null,"published_at":"2022-09-26T13:23:36+0300","created_at":"2022-09-26T13:23:36+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=70029179","insider_interview":null,"url":"https://api.hh.ru/vacancies/70029179?host=hh.ru","adv_response_url":"https://api.hh.ru/vacancies/70029179/adv_response?host=hh.ru","alternate_url":"https://hh.ru/vacancy/70029179","relations":[],"employer":{"id":"1424","name":"Odgers Berndtson","url":"https://api.hh.ru/employers/1424","alternate_url":"https://hh.ru/employer/1424","logo_urls":{"original":"https://hhcdn.ru/employer-logo-o
# ...

# %%
js = requests.get('https://api.hh.ru/vacancies?text=Аналитик&area=1&per_page=100&search_field=name').json()['items']

# %%
[str(x) for x in js]

# %%
'\n'.join([str(x) for x in js])
# Out:
# '{\'id\': \'70029179\', \'premium\': False, \'name\': \'Бизнес аналитик/Data аналитик (Elma)\', \'department\': None, \'has_test\': False, \'response_letter_required\': False, \'area\': {\'id\': \'1\', \'name\': \'Москва\', \'url\': \'https://api.hh.ru/areas/1\'}, \'salary\': {\'from\': 150000, \'to\': 170000, \'currency\': \'RUR\', \'gross\': True}, \'type\': {\'id\': \'open\', \'name\': \'Открытая\'}, \'address\': None, \'response_url\': None, \'sort_point_distance\': None, \'published_at\': \'2022-09-26T13:23:36+0300\', \'created_at\': \'2022-09-26T13:23:36+0300\', \'archived\': False, \'apply_alternate_url\': \'https://hh.ru/applicant/vacancy_response?vacancyId=70029179\', \'insider_interview\': None, \'url\': \'https://api.hh.ru/vacancies/70029179?host=hh.ru\', \'adv_response_url\': \'https://api.hh.ru/vacancies/70029179/adv_response?host=hh.ru\', \'alternate_url\': \'https://hh.ru/vacancy/70029179\', \'relations\': [], \'employer\': {\'id\': \'1424\', \'name\': \'Odgers Berndts
# ...

# %%
with open('/content/js.txt', 'w') as f:
  f.writelines([str(x) for x in js])
  f.close()

# %%
with open('/content/js.txt', 'r') as f:
  l=f.readlines()
  f.close()

# %%
l[0]

# %%
with open('/content/js.txt', 'w') as f:
  f.writelines([str(x)+'\n' for x in js])
  f.close()

# %%
with open('/content/js.txt', 'r') as f:
  l=[[y.split(': ')[1].replace("'",'') for y in x.split(',')[:3] if (y.find('name')>-1) or (y.find('id')>-1)] for x in f.readlines()]
  f.close()

# %%
l

# %%
l

# %%
#сделать список из 2000 вакансий где элеенетами будут списки из ид, имя, ср зп, работодатель. Превратить этот список в словарь и отсортировать по значению зп по убыванию

# %%
import requests
dct=dict()
for i in range(0,20):
  js= requests.get(URL+'&page='+str(i)).json()['items']
  for j in js:
    dict.update({'id':j['id'], 'name':j['name'], 'salary': j['salary'],'employer': j['employer']})
dct
# Out:
# {}

# %%
dct
# Out:
# {}

# %%
from requests.api import request
dct=dict()
for i in range(0,20):
  js= requests.get(URL+'&page='+str(i)).json()['items']
  for j in js:
    dct.update({j['id']:[{'name':j['name'],'salary': j['salary'],'employer': j['employer']}]})
dct

# %%
dict([{'id':1, 'salary':2},{'id':3, 'salary':4}])
# Out:
# {'id': 'salary'}

# %%
dict([('id',1), ('salary',2),('id',3), ('salary',4)])
# Out:
# {'id': 3, 'salary': 4}

# %%
l=list()
for i in range(0,20):
  js= requests.get(URL+'&page='+str(i)).json()['items']
  for j in js:
    l+=[{'id':j['id'],'name':j['name'],
         'salary':j['salary']['from'] if j['salary'] is not None else 0,
         'employer':j['employer']['name']}]
l

# %%
list(map(lambda x: 0 if x['salary'] is None else x['salary'], l))

# %%
[x['id'],['name'] for x in l]
# Out:
#   File "<ipython-input-180-bdb96d406c15>", line 1
#     [x['id'],['name'] for x in l]
#                         ^
# SyntaxError: invalid syntax

# %%
l1 = list(map(lambda x: {'id': x['id'], 'salary':0 if x['salary'] is None else x['salary']}, l))

# %%
sorted(l1,key = lambda x:x['salary'])

# %%
l1=[x['id'] for x in requests.get(URL.replace('area=1', 'area=2')).json()['items']]
l2=[x['id'] for x in requests.get(URL+'&area=2').json()['items']]
len(set(l2).intersection(set(l1)))
# Out:
# 19

# %%
[re.findall('[A-Z][A-Za-z]+[\/]?[A-Z][A-Za-z]*',x['requirement']) if x['requirement'] is not None else None for x in d.snippet.tolist()]

# %%
URL += "&area=2"

# %%
vacancies = requests.get(URL+'&page='+str(i)).json()['items']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-204-daa69635535f> in <module>
# ----> 1 d = DataFrame(vacancies)
#
# NameError: name 'DataFrame' is not defined

# %%
import pandas as pd
d = pd.DataFrame(vacancies)

# %%
from itertools import chain

# %%
vd = [re.findall('[A-Z][A-Za-z]+[\/]?[A-Z][A-Za-z]*',x['requirement']) if x['requirement'] is not None else None for x in d.snippet.tolist()]
vd = list(chain.from_iterable(vd))
vd

# %%
from collections import Counter
counter = Counter(vd)

# %%
dict(counter)
# Out:
# {'SQL': 19,
#  'BPMN': 5,
#  'EPC': 2,
#  'API': 3,
#  'ERP': 7,
#  'UML': 3,
#  'KPI': 1,
#  'MPLS': 1,
#  'BGP': 1,
#  'OSPF': 1,
#  'SQL/Python': 1,
#  'Story/Use': 1,
#  'QlikSence': 2,
#  'QlikAPI': 1,
#  'QlikEngine': 1,
#  'CJM': 1,
#  'IDEF': 2,
#  'ETL': 1,
#  'DBMS': 1,
#  'GreenPlum': 1,
#  'ClickHouse': 1,
#  'CRM': 2,
#  'SIEM': 1,
#  'XML': 1,
#  'JSON': 2,
#  'FlexCube': 1,
#  'PowerBI': 2,
#  'Python/R': 1,
#  'AppMetrica': 1,
#  'SimilarWeb': 1,
#  'AppAnnie': 1,
#  'VBA': 2,
#  'MDX': 1,
#  'MSSQL': 1,
#  'OLAP': 1,
#  'SSAS': 1,
#  'SSIS': 1,
#  'REST': 2,
#  'SOAP': 1,
#  'XML/XSD': 1,
#  'WSDL': 1,
#  'DWH': 1,
#  'CTEs': 1,
#  'PowerPoint': 1,
#  'BIG': 1,
#  'IDF': 2,
#  'DFD': 1,
#  'YouScan': 1,
#  'DELPHI': 2}
